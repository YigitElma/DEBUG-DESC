# %%
import sys
import os

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("../../../../"))

# %%
from desc import set_device
set_device("gpu")

# %%
import numpy as np
np.set_printoptions(linewidth=np.inf, precision=4, suppress=True, threshold=sys.maxsize)
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go
import functools
import scipy

# %%
import desc

from desc.basis import *
from desc.backend import *
from desc.compute import *
from desc.coils import *
from desc.equilibrium import *
from desc.examples import *
from desc.grid import *
from desc.geometry import *

from desc.objectives import *
from desc.objectives.objective_funs import *
from desc.objectives.getters import *
from desc.objectives.normalization import compute_scaling_factors
from desc.objectives.utils import *
from desc.optimize._constraint_wrappers import *

from desc.transform import Transform
from desc.plotting import *
from desc.optimize import *
from desc.perturbations import *
from desc.profiles import *
from desc.compat import *
from desc.utils import *
from desc.magnetic_fields import *

from desc.__main__ import main
from desc.vmec_utils import vmec_boundary_subspace
from desc.input_reader import InputReader
from desc.continuation import solve_continuation_automatic

print_backend_info()
# Out:
# DESC version=0.14.1+371.g6a626f49a.
# Using JAX backend: jax version=0.5.0, jaxlib version=0.5.0, dtype=float64.
# Using device: NVIDIA GeForce RTX 4080 Laptop GPU (id=0), with 10.64 GB available memory.

# %%
def plot_field_lines(field, equ, ntransit=200, nrho=9, size=0.4, outside=False):
    # for starting locations we'll pick positions on flux surfaces on the outboard midplane
    if outside:
        grid_trace = LinearGrid(rho=np.linspace(0, 1, 2))
        r0 = equ.compute("R", grid=grid_trace)["R"]
        z0 = equ.compute("Z", grid=grid_trace)["Z"]
        rmax = np.max(r0)
        rmin = np.min(r0)
        r0 = np.linspace(rmin, rmax + (rmax-rmin)*0.05, nrho)
        z0 = np.zeros_like(r0)
    else:
        grid_trace = LinearGrid(rho=np.linspace(0, 1, nrho))
        r0 = equ.compute("R", grid=grid_trace)["R"]
        z0 = equ.compute("Z", grid=grid_trace)["Z"]
    fig, ax = plot_surfaces(equ)
    fig, ax = poincare_plot(
        field,
        r0,
        z0,
        NFP=equ.NFP,
        ax=ax,
        color="k",
        size=size,
        ntransit=ntransit,
        bounds_R=(0.5, 1.5),
        bounds_Z=(-0.7, 0.7),
    )
    return fig, ax

def plot_init_coils_modular(equ, ncoils=3, r_over_a=3.5):
    coilset = initialize_modular_coils(
        equ, num_coils=ncoils, r_over_a=r_over_a
    ).to_FourierXYZ()
    fig = plot_3d(equ, "|B|")
    fig = plot_coils(coilset, fig=fig)
    return fig

# %%
def optimize_coils(equ, coilset0=None, curvature=True):
    if coilset0 is None:
        coilset0 = initialize_modular_coils(
            equ, num_coils=3, r_over_a=3.5
        ).to_FourierXYZ()
    # define our objective function (we will use a helper function here to make it easier to change weights later)
    weights = {
        "quadratic flux": 500,
        "coil-coil min dist": 100,
        "plasma-coil min dist": 10,
        "coil curvature": 250,
        "coil length": 20,
    }
    coil_grid = LinearGrid(N=50)
    # similarly define a grid on the plasma surface where B*n errors will be evaluated
    plasma_grid = LinearGrid(M=25, N=25, NFP=equ.NFP, sym=equ.sym)
    objs = [
        QuadraticFlux(
            equ,
            field=coilset0,
            # grid of points on plasma surface to evaluate normal field error
            eval_grid=plasma_grid,
            field_grid=coil_grid,
            vacuum=True,  # vacuum=True means we won't calculate the plasma contribution to B as it is zero
            weight=weights["quadratic flux"],
            bs_chunk_size=10,
        ),
        CoilLength(
            coilset0,
            bounds=(0, 2 * np.pi * (coilset0[0].compute("length")["length"])),
            normalize_target=True,  # target length is in meters, not normalized
            grid=coil_grid,
            weight=weights["coil length"],
        ),
    ]
    if curvature:
        objs += [
            CoilCurvature(
                coilset0,
                bounds=(-1, 2),
                normalize_target=False,  # we're giving bounds in normalized units
                grid=coil_grid,
                weight=weights["coil curvature"],
            )
        ]
    obj = ObjectiveFunction(objs)
    coil_indices_to_fix_current = [False for c in coilset0]
    coil_indices_to_fix_current[0] = True
    constraints = (FixCoilCurrent(coilset0, indices=coil_indices_to_fix_current),)

    optimizer = Optimizer("lsq-exact")

    (optimized_coilset,), _ = optimizer.optimize(
        coilset0,
        objective=obj,
        constraints=constraints,
        maxiter=200,
        verbose=3,
        ftol=1e-6,
        xtol=0,
        copy=True,
    )
    return optimized_coilset

# %%
def optimize_coils_regcoil(surf, equ, num_coils=16, return_k=False):
    # create the FourierCurrentPotentialField object from the constant offset surface we found in the previous cell
    surface_current_field = FourierCurrentPotentialField.from_surface(
        surf,
        I=0,
        # manually setting G to value needed to provide the equilibrium's toroidal flux,
        # though this is not necessary as it gets set automatically inside the solve_regularized_surface_current function
        G=np.asarray(
            [
                -equ.compute("G", grid=LinearGrid(rho=np.array(1.0)))["G"][0]
                / mu_0
                * 2
                * np.pi
            ]
        ),
        # set symmetry of the current potential, "sin" is usually expected for stellarator-symmetric surfaces and equilibria
        sym_Phi="sin",
    )

    surface_current_field.change_Phi_resolution(M=12, N=12)

    # create the evaluation grid (where Bn will be minimized on plasma surface)
    # and source grid (discretizes the source K for Biot-Savart and where |K| will be penalized on winding surface)
    Megrid = 20
    Negrid = 20
    Msgrid = 20
    Nsgrid = 20

    eval_grid = LinearGrid(M=Megrid, N=Negrid, NFP=equ.NFP, sym=False)
    # ensure that sym=False for source grid so the field evaluated from the surface current is accurate
    # (i.e. must evaluate source over whole surface, not just the symmetric part)
    # NFP>1 is ok, as we internally will rotate the source through the field periods to sample entire winding surface
    sgrid = LinearGrid(M=Msgrid, N=Nsgrid, NFP=equ.NFP, sym=False)

    lambda_regularization = np.append(np.array([0]), np.logspace(-30, 1, 20))

    # solve_regularized_surface_current method runs the REGCOIL algorithm
    fields, data = solve_regularized_surface_current(
        surface_current_field,  # the surface current field whose geometry and Phi resolution will be used
        eq=equ,  # the Equilibrium object to minimize Bn on the surface of
        source_grid=sgrid,  # source grid
        eval_grid=eval_grid,  # evaluation grid
        current_helicity=(
            1*surface_current_field.NFP,
            -1,
        ),  # pair of integers (M_coil, N_coil), determines topology of contours (almost like  QS helicity),
        #  M_coil is the number of times the coil transits poloidally before closing back on itself
        # and N_coil is the toroidal analog (if M_coil!=0 and N_coil=0, we have modular coils, if both M_coil
        # and N_coil are nonzero, we have helical coils)
        # we pass in an array to perform scan over the regularization parameter (which we call lambda_regularization)
        # to see tradeoff between Bn and current complexity
        lambda_regularization=lambda_regularization,
        # lambda_regularization can also be just a single number in which case no scan is performed
        vacuum=True,  # this is a vacuum equilibrium, so no need to calculate the Bn contribution from the plasma currents
        regularization_type="regcoil",
        chunk_size=40,
    )
    surface_current_field = fields[
        0
    ]  # fields is a list of FourierCurrentPotentialField objects

    if return_k:
        return surface_current_field
    else:
        coilset = surface_current_field.to_CoilSet(num_coils=num_coils, stell_sym=True)
        return coilset

# %% [markdown]
# # Get Equilibria

# %%
eq = desc.io.load("eq-org-giuliani2023-island-LMN10.h5")
eq0 = desc.io.load("eq-org-giuliani2023-island-LMN16.h5")
plot_1d(eq, "iota")
plot_1d(eq0, "iota")
# Out:
# (<Figure size 384.076x384.076 with 1 Axes>,
#  <Axes: xlabel='$\\rho$', ylabel='$ \\iota ~(~)$'>)

# %%
coil_grid = LinearGrid(N=50)
plasma_grid = LinearGrid(M=25, N=25, NFP=eq.NFP, sym=eq.sym)
plot_grid = LinearGrid(M=20, N=40, NFP=1, endpoint=True)

# %% [markdown]
# # Fix all n=0 modes
#
# Instead of fixing a fixed $\zeta$ cross-section, now, we will fix only the n=0 modes. Basically, fix the average cross-section.

# %%
def solve_n0_fixed(eq2solve, **kwargs):
    jac_chunk_size = kwargs.pop("jac_chunk_size", None)
    R_modes = eq2solve.R_basis.modes[eq2solve.R_basis.modes[:, 2] == 0]
    Z_modes = eq2solve.Z_basis.modes[eq2solve.Z_basis.modes[:, 2] == 0]
    cons = (
        FixModeR(eq2solve, modes=R_modes),
        FixModeZ(eq2solve, modes=Z_modes),
        FixPressure(eq2solve),
        FixPsi(eq2solve),
        FixCurrent(eq2solve),
        FixSheetCurrent(eq2solve),
        FixLambdaGauge(eq2solve),
    )
    cons = maybe_add_self_consistency(eq2solve, cons)
    obj = ObjectiveFunction(ForceBalance(eq2solve, jac_chunk_size=jac_chunk_size))
    eq2solve.solve(
        constraints=cons,
        objective=obj,
        **kwargs,
    )

# %%
eq_n0 = eq.copy()
solve_n0_fixed(eq_n0, maxiter=850, ftol=1e-3, verbose=3)
# Out:
# Building objective: force
# Precomputing transforms
# Timer: Precomputing transforms = 72.6 ms
# Timer: Objective build = 153 ms
# Building objective: fix mode R
# Building objective: fix mode Z
# Building objective: fixed pressure
# Building objective: fixed Psi
# Building objective: fixed current
# Building objective: fixed sheet current
# Building objective: lambda gauge
# Building objective: self_consistency lcfs R
# Building objective: self_consistency lcfs Z
# Building objective: self_consistency axis R
# Building objective: self_consistency axis Z
# Timer: Objective build = 231 ms
# Timer: LinearConstraintProjection build = 2.82 sec
# Number of parameters: 2010
# Number of objectives: 9922
# Timer: Initializing the optimization = 3.29 sec
#
# Starting optimization
# Using method: lsq-exact
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1
#       312            347         5.419e-09      8.685e-12      6.177e-04      9.427e-07
#       313            348         5.411e-09      8.588e-12      6.135e-04      9.249e-07
#       314            349         5.402e-09      8.542e-12      6.097e-04      8.960e-07
#       315            351         5.395e-09      6.917e-12      3.065e-04      2.536e-07
#       316            352         5.389e-09      5.785e-12      6.068e-04      8.332e-07
#       317            353         5.381e-09      8.091e-12      6.001e-04      8.419e-07
#       318            355         5.375e-09      6.471e-12      3.018e-04      2.251e-07
#       319            356         5.369e-09      5.863e-12      5.983e-04      7.674e-07
#       320            357         5.361e-09      7.871e-12      5.927e-04      7.723e-07
#       321            359         5.355e-09      6.046e-12      2.981e-04      2.017e-07
#       322            360         5.349e-09      5.908e-12      5.918e-04      6.967e-07
#       323            362         5.343e-09      5.715e-12      2.959e-04      1.895e-07
#       324            363         5.338e-09      5.924e-12      5.885e-04      6.547e-07
#       325            365         5.332e-09      5.520e-12      2.943e-04      1.770e-07
#       326            366         5.326e-09      5.918e-12      5.858e-04      6.154e-07
#       327            368         5.321e-09      5.356e-12      2.930e-04      1.649e-07
#       328            369         5.315e-09      5.897e-12      5.837e-04      5.784e-07
#       329            371         5.310e-09      5.216e-12      2.920e-04      1.537e-07
# Optimization terminated successfully.
# `ftol` condition satisfied. (ftol=1.00e-03)
#          Current function value: 5.310e-09
#          Total delta_x: 1.248e-01
#          Iterations: 329
#          Function evaluations: 371
#          Jacobian evaluations: 330
# Timer: Solution time = 10.3 min
# Timer: Avg time per step = 1.87 sec
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      9.093e-09  -->   5.310e-09,
# Maximum absolute Force error:                                8.805e+03  -->   6.257e+03 (N)
# Minimum absolute Force error:                                2.451e-02  -->   8.539e-03 (N)
# Average absolute Force error:                                3.091e+02  -->   2.370e+02 (N)
# Maximum absolute Force error:                                5.370e-05  -->   3.816e-05 (normalized)
# Minimum absolute Force error:                                1.495e-10  -->   5.208e-11 (normalized)
# Average absolute Force error:                                1.885e-06  -->   1.446e-06 (normalized)
# Fixed-R modes error:                                         0.000e+00  -->   0.000e+00 (m)
# Fixed-Z modes error:                                         0.000e+00  -->   3.388e-21 (m)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed current profile error:                                 0.000e+00  -->   0.000e+00 (A)
# Fixed sheet current error:                                   0.000e+00  -->   0.000e+00 (~)
# lambda gauge error:                                          0.000e+00  -->   0.000e+00 (rad)
# LCFS R self consistency error:                               2.221e-16  -->   5.442e-17 (m)
# LCFS Z self consistency error:                               2.803e-17  -->   8.163e-17 (m)
# Axis R self consistency error:                               2.222e-16  -->   2.238e-16 (m)
# Axis Z self consistency error:                               1.393e-18  -->   5.551e-17 (m)
# ==============================================================================================================

# %%
eq_n0.save(f"eq-fixed-n0-giuliani2023-island-L{eq_n0.L}M{eq_n0.M}N{eq_n0.N}.h5")

# %%
eq_n0 = desc.io.load(f"eq-fixed-n0-giuliani2023-island-L10M10N10.h5")

# %%
plot_comparison([eq, eq_n0], labels=["original", "fix n=0 modes"])
# Out:
# (<Figure size 1152.23x960.189 with 6 Axes>,
#  array([<Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.000$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.167$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.333$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.500$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.667$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.833$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>], dtype=object))

# %%
regcoil = 1
return_k = 1
if regcoil:
    # create the constant offset surface
    surf3 = eq_n0.surface.constant_offset_surface(
        offset=0.25,  # desired offset
        M=16,  # Poloidal resolution of desired offset surface
        N=16,  # Toroidal resolution of desired offset surface
        grid=LinearGrid(M=32, N=32, NFP=eq_n0.NFP),
    )  # grid of points on base surface to evaluate unit normal and find points on offset surface,
    # generally should be twice the desired resolution
    if return_k:
        optimized_coilset3 = optimize_coils_regcoil(
            surf3, eq_n0, num_coils=8, return_k=True
        )
    else:
        optimized_coilset3 = optimize_coils_regcoil(surf3, eq_n0, num_coils=8)
else:
    coilset0 = initialize_modular_coils(eq_n0, num_coils=3, r_over_a=4).to_FourierXYZ()
    optimized_coilset3 = optimize_coils(eq_n0, coilset0=coilset0, curvature=True)
# Out:
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 0.00000e+00
# ##########################################################
# chi^2 B = 2.34519e-05
# min Bnormal = 8.38353e-17 (T)
# Max Bnormal = 3.23926e-05 (T)
# Avg Bnormal = 6.31043e-06 (T)
# min Bnormal = 8.65861e-18 (unitless)
# Max Bnormal = 3.34555e-06 (unitless)
# Avg Bnormal = 6.51749e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.00000e-30
# ##########################################################
# chi^2 B = 2.34519e-05
# min Bnormal = 7.69411e-17 (T)
# Max Bnormal = 3.23926e-05 (T)
# Avg Bnormal = 6.31043e-06 (T)
# min Bnormal = 7.94656e-18 (unitless)
# Max Bnormal = 3.34555e-06 (unitless)
# Avg Bnormal = 6.51749e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 4.28133e-29
# ##########################################################
# chi^2 B = 2.34519e-05
# min Bnormal = 7.90094e-17 (T)
# Max Bnormal = 3.23926e-05 (T)
# Avg Bnormal = 6.31043e-06 (T)
# min Bnormal = 8.16018e-18 (unitless)
# Max Bnormal = 3.34555e-06 (unitless)
# Avg Bnormal = 6.51749e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.83298e-27
# ##########################################################
# chi^2 B = 2.34519e-05
# min Bnormal = 8.31459e-17 (T)
# Max Bnormal = 3.23928e-05 (T)
# Avg Bnormal = 6.31040e-06 (T)
# min Bnormal = 8.58740e-18 (unitless)
# Max Bnormal = 3.34556e-06 (unitless)
# Avg Bnormal = 6.51745e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 7.84760e-26
# ##########################################################
# chi^2 B = 2.34520e-05
# min Bnormal = 8.83166e-17 (T)
# Max Bnormal = 3.23986e-05 (T)
# Avg Bnormal = 6.30885e-06 (T)
# min Bnormal = 9.12143e-18 (unitless)
# Max Bnormal = 3.34616e-06 (unitless)
# Avg Bnormal = 6.51586e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 3.35982e-24
# ##########################################################
# chi^2 B = 2.35442e-05
# min Bnormal = 7.72858e-17 (T)
# Max Bnormal = 3.25820e-05 (T)
# Avg Bnormal = 6.25489e-06 (T)
# min Bnormal = 7.98216e-18 (unitless)
# Max Bnormal = 3.36510e-06 (unitless)
# Avg Bnormal = 6.46012e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.43845e-22
# ##########################################################
# chi^2 B = 3.71876e-05
# min Bnormal = 3.62652e-17 (T)
# Max Bnormal = 4.18157e-05 (T)
# Avg Bnormal = 7.33729e-06 (T)
# min Bnormal = 3.74551e-18 (unitless)
# Max Bnormal = 4.31877e-06 (unitless)
# Avg Bnormal = 7.57803e-07 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 6.15848e-21
# ##########################################################
# chi^2 B = 1.25454e-04
# min Bnormal = 1.14445e-17 (T)
# Max Bnormal = 6.58942e-05 (T)
# Avg Bnormal = 1.32742e-05 (T)
# min Bnormal = 1.18200e-18 (unitless)
# Max Bnormal = 6.80563e-06 (unitless)
# Avg Bnormal = 1.37097e-06 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 2.63665e-19
# ##########################################################
# chi^2 B = 7.46260e-04
# min Bnormal = 2.13886e-18 (T)
# Max Bnormal = 1.69547e-04 (T)
# Avg Bnormal = 3.16438e-05 (T)
# min Bnormal = 2.20904e-19 (unitless)
# Max Bnormal = 1.75110e-05 (unitless)
# Avg Bnormal = 3.26820e-06 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.12884e-17
# ##########################################################
# chi^2 B = 5.91554e-03
# min Bnormal = 4.03682e-18 (T)
# Max Bnormal = 4.33822e-04 (T)
# Avg Bnormal = 8.81954e-05 (T)
# min Bnormal = 4.16927e-19 (unitless)
# Max Bnormal = 4.48056e-05 (unitless)
# Avg Bnormal = 9.10892e-06 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 4.83293e-16
# ##########################################################
# chi^2 B = 9.36084e-02
# min Bnormal = 5.82669e-18 (T)
# Max Bnormal = 1.85190e-03 (T)
# Avg Bnormal = 3.75542e-04 (T)
# min Bnormal = 6.01788e-19 (unitless)
# Max Bnormal = 1.91266e-04 (unitless)
# Avg Bnormal = 3.87864e-05 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 2.06914e-14
# ##########################################################
# chi^2 B = 3.57640e+00
# min Bnormal = 7.81498e-18 (T)
# Max Bnormal = 9.89786e-03 (T)
# Avg Bnormal = 2.44513e-03 (T)
# min Bnormal = 8.07140e-19 (unitless)
# Max Bnormal = 1.02226e-03 (unitless)
# Avg Bnormal = 2.52536e-04 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 8.85867e-13
# ##########################################################
# chi^2 B = 5.72116e+01
# min Bnormal = 8.10284e-18 (T)
# Max Bnormal = 4.03216e-02 (T)
# Avg Bnormal = 1.09848e-02 (T)
# min Bnormal = 8.36871e-19 (unitless)
# Max Bnormal = 4.16446e-03 (unitless)
# Avg Bnormal = 1.13452e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 3.79269e-11
# ##########################################################
# chi^2 B = 7.96510e+01
# min Bnormal = 7.88654e-18 (T)
# Max Bnormal = 4.71287e-02 (T)
# Avg Bnormal = 1.31522e-02 (T)
# min Bnormal = 8.14531e-19 (unitless)
# Max Bnormal = 4.86750e-03 (unitless)
# Avg Bnormal = 1.35837e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.62378e-09
# ##########################################################
# chi^2 B = 8.03577e+01
# min Bnormal = 7.89764e-18 (T)
# Max Bnormal = 4.73236e-02 (T)
# Avg Bnormal = 1.32152e-02 (T)
# min Bnormal = 8.15677e-19 (unitless)
# Max Bnormal = 4.88764e-03 (unitless)
# Avg Bnormal = 1.36488e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 6.95193e-08
# ##########################################################
# chi^2 B = 8.03744e+01
# min Bnormal = 7.81172e-18 (T)
# Max Bnormal = 4.73282e-02 (T)
# Avg Bnormal = 1.32167e-02 (T)
# min Bnormal = 8.06803e-19 (unitless)
# Max Bnormal = 4.88811e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 2.97635e-06
# ##########################################################
# chi^2 B = 8.03748e+01
# min Bnormal = 7.81173e-18 (T)
# Max Bnormal = 4.73283e-02 (T)
# Avg Bnormal = 1.32168e-02 (T)
# min Bnormal = 8.06804e-19 (unitless)
# Max Bnormal = 4.88812e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.27427e-04
# ##########################################################
# chi^2 B = 8.03748e+01
# min Bnormal = 7.89791e-18 (T)
# Max Bnormal = 4.73283e-02 (T)
# Avg Bnormal = 1.32168e-02 (T)
# min Bnormal = 8.15705e-19 (unitless)
# Max Bnormal = 4.88812e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 5.45559e-03
# ##########################################################
# chi^2 B = 8.03748e+01
# min Bnormal = 7.89791e-18 (T)
# Max Bnormal = 4.73283e-02 (T)
# Avg Bnormal = 1.32168e-02 (T)
# min Bnormal = 8.15705e-19 (unitless)
# Max Bnormal = 4.88812e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 2.33572e-01
# ##########################################################
# chi^2 B = 8.03748e+01
# min Bnormal = 7.89791e-18 (T)
# Max Bnormal = 4.73283e-02 (T)
# Avg Bnormal = 1.32168e-02 (T)
# min Bnormal = 8.15705e-19 (unitless)
# Max Bnormal = 4.88812e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)
# ##########################################################
# Calculating Phi_SV for lambda_regularization = 1.00000e+01
# ##########################################################
# chi^2 B = 8.03748e+01
# min Bnormal = 7.81173e-18 (T)
# Max Bnormal = 4.73283e-02 (T)
# Avg Bnormal = 1.32168e-02 (T)
# min Bnormal = 8.06804e-19 (unitless)
# Max Bnormal = 4.88812e-03 (unitless)
# Avg Bnormal = 1.36504e-03 (unitless)

# %%
eq_n0.surface = eq_n0.get_surface_at(rho=1.0)
if not return_k:
    fig = plot_3d(
        eq_n0.surface,
        "B*n",
        field=optimized_coilset3,
        field_grid=coil_grid,
        grid=plot_grid,
    )

    fig = plot_coils(optimized_coilset3, fig=fig)
    fig.show()

# %%
optimized_coilset3.save(
    f"surface-K-fixed-n0-giuliani2023-L{eq_n0.L}M{eq_n0.M}N{eq_n0.N}.h5"
)

# %%
optimized_coilset3 = desc.io.load(
    f"surface-K-fixed-n0-giuliani2023-L{eq_n0.L}M{eq_n0.M}N{eq_n0.N}.h5"
)

# %%
fig, ax = plot_field_lines(optimized_coilset3, eq_n0, nrho=18, ntransit=200, size=0.2, outside=False)
plt.show()
# fig.savefig(f"plot-giuliani2023-fixed-n0-L{eq_n0.L}M{eq_n0.M}N{eq_n0.N}.png", dpi=1000)

# %%
levels = np.logspace(-6, 0, 50)
grid = LinearGrid(L=40, M=30, zeta=6, NFP=eq_n0.NFP, sym=False, axis=False, endpoint=False)
fig, ax = plot_section(eq_n0, "|F|", grid=grid, log=True, norm_F=True, levels=levels)
fig, ax = plot_surfaces(eq_n0, ax=ax, theta=0)

# %%
levels = np.logspace(-6,0, 7)
fig, ax = plot_section(eq_n0, "|F|", phi=3, log=True, norm_F=True, levels=levels)
fig.suptitle("After Fixed n=0 modes");
fig, ax = plot_section(eq, "|F|", phi=3, log=True, norm_F=True, levels=levels)
fig.suptitle("Original");

# %%
plot_1d(eq, "iota")
plt.title("Original with LMN=10")
plot_1d(eq_n0, "iota")
plt.title("Fixed N=0 with LMN=10");

# %%
plot_1d(eq, "current")
plt.title("Original with LMN=10")
plot_1d(eq_n0, "current")
plt.title("Fixed N=0 with LMN=10");

# %%
plot_boozer_surface(eq)
plt.title("Original with LMN=10")
plot_boozer_surface(eq_n0)
plt.title("After Fixed n=0 modes");

# %%
eq_n0.surface = eq_n0.get_surface_at(rho=1.0)
eq_n0.solve(maxiter=100, verbose=3, ftol=1e-3)
plot_comparison([eq, eq_n0], labels=["original", "fixed n=0 modes"])
# Out:
# Building objective: force
# Precomputing transforms
# Timer: Precomputing transforms = 61.1 ms
# Timer: Objective build = 74.0 ms
# Building objective: fixed LCFS R
# Building objective: fixed LCFS Z
# Building objective: fixed Psi
# Building objective: fixed pressure
# Building objective: fixed current
# Building objective: fixed sheet current
# Building objective: self_consistency lcfs R
# Building objective: self_consistency lcfs Z
# Building objective: lambda gauge
# Building objective: self_consistency axis R
# Building objective: self_consistency axis Z
# Timer: Objective build = 169 ms
# Timer: LinearConstraintProjection build = 1.97 sec
# Number of parameters: 1635
# Number of objectives: 9922
# Timer: Initializing the optimization = 2.27 sec
#
# Starting optimization
# Using method: lsq-exact
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1          3.444e-09                                    5.579e-07
#        1              4          3.434e-09      1.035e-11      6.839e-04      1.745e-06
#        2              5          3.419e-09      1.453e-11      6.780e-04      1.620e-06
#        3              6          3.406e-09      1.330e-11      6.744e-04      1.560e-06
#        4              7          3.394e-09      1.219e-11      6.725e-04      1.504e-06
#        5              8          3.383e-09      1.115e-11      6.718e-04      1.453e-06
#        6              9          3.372e-09      1.017e-11      6.717e-04      1.407e-06
#        7             10          3.363e-09      9.245e-12      6.718e-04      1.367e-06
#        8             11          3.355e-09      8.352e-12      6.718e-04      1.331e-06
#        9             12          3.347e-09      7.488e-12      6.716e-04      1.301e-06
#       10             13          3.341e-09      6.648e-12      6.712e-04      1.274e-06
#       11             14          3.335e-09      5.830e-12      6.703e-04      1.251e-06
#       12             15          3.330e-09      5.030e-12      6.692e-04      1.232e-06
#       13             16          3.326e-09      4.247e-12      6.677e-04      1.216e-06
#       14             17          3.322e-09      3.480e-12      6.659e-04      1.203e-06
#       15             18          3.319e-09      2.729e-12      6.637e-04      1.193e-06
# Optimization terminated successfully.
# `ftol` condition satisfied. (ftol=1.00e-03)
#          Current function value: 3.319e-09
#          Total delta_x: 9.911e-03
#          Iterations: 15
#          Function evaluations: 18
#          Jacobian evaluations: 16
# Timer: Solution time = 28.2 sec
# Timer: Avg time per step = 1.76 sec
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      3.444e-09  -->   3.319e-09,
# Maximum absolute Force error:                                5.337e+03  -->   5.457e+03 (N)
# Minimum absolute Force error:                                6.074e-02  -->   7.844e-03 (N)
# Average absolute Force error:                                1.890e+02  -->   1.857e+02 (N)
# Maximum absolute Force error:                                3.255e-05  -->   3.328e-05 (normalized)
# Minimum absolute Force error:                                3.705e-10  -->   4.784e-11 (normalized)
# Average absolute Force error:                                1.153e-06  -->   1.133e-06 (normalized)
# LCFS R error:                                                0.000e+00  -->   9.030e-18 (m)
# LCFS Z error:                                                0.000e+00  -->   9.156e-18 (m)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed current profile error:                                 0.000e+00  -->   0.000e+00 (A)
# Fixed sheet current error:                                   0.000e+00  -->   0.000e+00 (~)
# ==============================================================================================================
# (<Figure size 1152.23x960.189 with 6 Axes>,
#  array([<Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.000$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.167$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.333$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.500$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.667$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>, <Axes: title={'center': '$\\phi \\cdot N_{FP}/2\\pi = 0.833$'}, xlabel='$R ~(\\mathrm{m})$', ylabel='$Z ~(\\mathrm{m})$'>], dtype=object))
