# %%
import sys
import os

sys.path.insert(0, os.path.abspath("."))
sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("../../"))

from desc import set_device
set_device("gpu")

# %%
import numpy as np
np.set_printoptions(linewidth=np.inf, precision=4, suppress=True, threshold=sys.maxsize)
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go

# %%
import desc

from desc.basis import *
from desc.backend import *
from desc.compute import *
from desc.coils import *
from desc.equilibrium import *
from desc.examples import *
from desc.grid import *
from desc.geometry import *
from desc.io import *

from desc.objectives import *
from desc.objectives.objective_funs import *
from desc.objectives.getters import *
from desc.objectives.normalization import compute_scaling_factors
from desc.objectives.utils import *
from desc.optimize._constraint_wrappers import *

from desc.transform import Transform
from desc.plotting import *
from desc.optimize import *
from desc.perturbations import *
from desc.profiles import *
from desc.compat import *
from desc.utils import *
from desc.magnetic_fields import *
from desc.particles import *
from diffrax import *

from desc.__main__ import main
from desc.vmec_utils import vmec_boundary_subspace
from desc.input_reader import InputReader
from desc.continuation import solve_continuation_automatic
from desc.compute.data_index import register_compute_fun
from desc.optimize.utils import solve_triangular_regularized

print_backend_info()
# Out:
# DESC version=0.16.0+36.gb29e1911d.
# Using JAX backend: jax version=0.6.2, jaxlib version=0.6.2, dtype=float64.
# Using device: NVIDIA GeForce RTX 4080 Laptop GPU (id=0), with 11.61 GB available memory.

# %%
from extra_coil_objectives import CoilBounds, SurfaceMatch

# %% [markdown]
# # About this Notebook
#
# We will optimize an umbilic coil for HBT hybrid design.

# %%
eq = load("eq_final2.h5")
base_coils = load("hbt_default_coils.h5")    # this is a MixedCoilSet

# %%
minor_radius = eq.compute("a")["a"]
offset = 1.8 * minor_radius
zeta = np.linspace(0, 2 * np.pi, 41)
helical_offset = 0
R0 = 1.0
# assumes that theta = zeta - helical_offset for n/m=1 umbilic coil
# use m * theta - n * zeta = - helical_offset for general n/m
# parametrization of a curve is R = R0 + offset * cos(theta)
# and Z = offset * sin(theta)
R = R0 + offset * np.cos(zeta - helical_offset)
Z = offset * np.sin(zeta - helical_offset)

data = jnp.vstack([R, zeta, Z]).T
umbilic_coil = FourierRZCoil.from_values(
    current=-2.1e3,
    coords=data,
    N=10,
    basis="rpz",
)
coil_grid = LinearGrid(N=50)

# %%
fig = plot_coils(umbilic_coil)
plot_3d(eq, "|B|", fig=fig)

# %% [markdown]
# ## Combined Field

# %%
field = base_coils.copy()
field.append(umbilic_coil)

# %% [markdown]
# ## Constraints

# %%
params_to_fix_field = [
    # tf coilset
    {"current": True, "r_n": True, "center": True, "normal": True},
    # vf inner coilset
    {"current": True, "r_n": True, "center": True, "normal": True},
    # vf outer coilset
    {"current": True, "r_n": True, "center": True, "normal": True},
    # oh inner coilset
    {"current": True, "r_n": True, "center": True, "normal": True},
    # oh outer coilset
    {"current": True, "r_n": True, "center": True, "normal": True},
    # umbilic coil
    {"current": False, "R_n": False, "Z_n": False, "rotmat": False, "shift": False},
]

# %%
k = 1

modes_R = np.vstack(
    (
        [0, 0, 0],
        eq.surface.R_basis.modes[np.max(np.abs(eq.surface.R_basis.modes), 1) > k, :],
    )
)
modes_Z = eq.surface.Z_basis.modes[np.max(np.abs(eq.surface.Z_basis.modes), 1) > k, :]

constraints = (
    ForceBalance(eq=eq),
    FixBoundaryR(eq=eq, modes=modes_R),
    FixBoundaryZ(eq=eq, modes=modes_Z),
    FixPsi(eq=eq),
    FixPressure(eq=eq),
    FixParameters(
        field,
        params_to_fix_field,
    ),
)
if eq.current is not None:
    constraints += (FixCurrent(eq=eq),)
else:
    constraints += (FixIota(eq=eq),)
    
# build constraints to check broadcasting
for con in constraints:
    con.build()
# Out:
# Precomputing transforms

# %% [markdown]
# ## Objectives

# %%
len1 = 2 * np.pi * 1.45
len2 = 2 * np.pi * 1.05

dist1 = np.inf
dist2 = 0.1

objective = ObjectiveFunction(
    (
        BoundaryError(
            eq,
            field,
            deriv_mode="fwd",
            weight=60,
            bs_chunk_size=10,
            B_plasma_chunk_size=10,
        ),
        # CoilSetMinDistance(
        #     field,
        #     bounds=(0.1, 100),
        #     grid=LinearGrid(N=100),
        #     weight=20,
        #     deriv_mode="fwd",
        # ),
        CoilLength(
            field,
            bounds=(0, len2),
            normalize_target=True,
            weight=[0, 0, 0, 0, 0, 5],
            grid=coil_grid,
            deriv_mode="fwd",
        ),
        PlasmaCoilSetMinDistance(
            eq,
            field,
            bounds=(0.04, np.inf),
            normalize_target=True,
            coil_grid=coil_grid,
            eq_fixed=True,
            weight=500,
        ),
        CoilBounds(
            field,
            target=0,
            normalize_target=True,
            grid=coil_grid,
            weight=[0, 0, 0, 0, 0, 10],
        ),
    ),
    deriv_mode="batched",
)

optimizer = Optimizer("proximal-lsq-exact")

# %% [markdown]
# ## Optimize

# %%
[eq, field_opt], out = optimizer.optimize(
    [eq, field],
    objective,
    constraints,
    verbose=3,
    options={},
    copy=True,
    ftol=1e-10,
    xtol=1e-10,
    gtol=1e-10,
    maxiter=0,
)
# Out:
# Building objective: Boundary error
# Precomputing transforms
# Timer: Precomputing transforms = 150 ms
# Building objective: coil length
# Precomputing transforms
# Timer: Precomputing transforms = 17.7 ms
# Building objective: plasma-coil minimum distance
# Building objective: coil bound
# Precomputing transforms
# Timer: Precomputing transforms = 7.48 ms
# Timer: Objective build = 5.56 sec
# Timer: Objective build = 2.38 ms
# Timer: Objective build = 1.60 ms
# Timer: Eq Update LinearConstraintProjection build = 5.95 sec
# Timer: Proximal projection build = 1.62 min
# Building objective: fixed shift
# Building objective: fixed rotation
# Timer: Objective build = 507 ms
# Timer: LinearConstraintProjection build = 9.82 sec
# Number of parameters: 51
# Number of objectives: 6547
# Timer: Initializing the optimization = 1.79 min
#
# Starting optimization
# Using method: proximal-lsq-exact
# Solver options:
# ------------------------------------------------------------
# Maximum Function Evaluations       : 1
# Maximum Allowed Total Δx Norm      : inf
# Scaled Termination                 : True
# Trust Region Method                : qr
# Initial Trust Radius               : 3.306e+02
# Maximum Trust Radius               : inf
# Minimum Trust Radius               : 2.220e-16
# Trust Radius Increase Ratio        : 2.000e+00
# Trust Radius Decrease Ratio        : 2.500e-01
# Trust Radius Increase Threshold    : 7.500e-01
# Trust Radius Decrease Threshold    : 2.500e-01
# ------------------------------------------------------------
#
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1          1.705e+03                                    5.240e+01
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.705e+03
#          Total delta_x: 0.000e+00
#          Iterations: 0
#          Function evaluations: 1
#          Jacobian evaluations: 1
# Timer: Solution time = 3.41 min
# Timer: Avg time per step = 3.41 min
# ==============================================================================================================
#                                                                  Start  -->   End
# Total (sum of squares):                                      1.705e+03  -->   1.705e+03,
# Maximum absolute Boundary normal field error:                7.805e-03  -->   7.806e-03 (T*m^2)
# Minimum absolute Boundary normal field error:                2.959e-18  -->   7.180e-18 (T*m^2)
# Average absolute Boundary normal field error:                1.882e-03  -->   1.882e-03 (T*m^2)
# Maximum absolute Boundary normal field error:                1.261e-01  -->   1.261e-01 (normalized)
# Minimum absolute Boundary normal field error:                4.782e-17  -->   1.160e-16 (normalized)
# Average absolute Boundary normal field error:                3.040e-02  -->   3.040e-02 (normalized)
# Maximum absolute Boundary magnetic pressure error:           4.932e-03  -->   4.932e-03 (T^2*m^2)
# Minimum absolute Boundary magnetic pressure error:           3.710e-05  -->   3.698e-05 (T^2*m^2)
# Average absolute Boundary magnetic pressure error:           1.750e-03  -->   1.750e-03 (T^2*m^2)
# Maximum absolute Boundary magnetic pressure error:           1.516e-01  -->   1.516e-01 (normalized)
# Minimum absolute Boundary magnetic pressure error:           1.141e-03  -->   1.137e-03 (normalized)
# Average absolute Boundary magnetic pressure error:           5.381e-02  -->   5.381e-02 (normalized)
# Maximum Coil length:                                         6.449e+00  -->   6.449e+00 (m)
# Minimum Coil length:                                         6.449e+00  -->   6.449e+00 (m)
# Average Coil length:                                         6.449e+00  -->   6.449e+00 (m)
# Maximum Coil length:                                         1.459e+01  -->   1.459e+01 (normalized)
# Minimum Coil length:                                         1.459e+01  -->   1.459e+01 (normalized)
# Average Coil length:                                         1.459e+01  -->   1.459e+01 (normalized)
# Maximum Minimum plasma-coil distance:                        7.786e-01  -->   7.786e-01 (m)
# Minimum Minimum plasma-coil distance:                        2.673e-02  -->   2.673e-02 (m)
# Average Minimum plasma-coil distance:                        4.051e-01  -->   4.051e-01 (m)
# Maximum Minimum plasma-coil distance:                        6.148e+00  -->   6.148e+00 (normalized)
# Minimum Minimum plasma-coil distance:                        2.111e-01  -->   2.111e-01 (normalized)
# Average Minimum plasma-coil distance:                        3.199e+00  -->   3.199e+00 (normalized)
# Maximum absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (m)
# Minimum absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (m)
# Average absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (m)
# Maximum absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (normalized)
# Minimum absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (normalized)
# Average absolute Coil bound:                                 0.000e+00  -->   0.000e+00 (normalized)
# Maximum absolute Force error:                                3.703e+01  -->   3.697e+01 (N)
# Minimum absolute Force error:                                2.697e-06  -->   1.977e-05 (N)
# Average absolute Force error:                                4.253e-01  -->   4.210e-01 (N)
# Maximum absolute Force error:                                1.450e-04  -->   1.447e-04 (normalized)
# Minimum absolute Force error:                                1.056e-11  -->   7.738e-11 (normalized)
# Average absolute Force error:                                1.665e-06  -->   1.648e-06 (normalized)
# R boundary error:                                            0.000e+00  -->   4.039e-19 (m)
# Z boundary error:                                            0.000e+00  -->   3.919e-19 (m)
# Fixed Psi error:                                             0.000e+00  -->   0.000e+00 (Wb)
# Fixed pressure profile error:                                0.000e+00  -->   0.000e+00 (Pa)
# Fixed parameters error:                                      0.000e+00  -->   0.000e+00 (~)
# Fixed current profile error:                                 0.000e+00  -->   3.725e-09 (A)
# ==============================================================================================================

# %%
fig = plot_coils(field_opt)
plot_3d(eq, "|B|", fig=fig)
