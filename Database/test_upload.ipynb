# %%
import stelladb
# Out:
# DESC version 0.11.0+41.g8700eb659.dirty,using JAX backend, jax version=0.4.25, jaxlib version=0.4.25, dtype=float64
# Using device: CPU, with 10.42 GB available memory

# %%
from desc.io.equilibrium_io import desc_to_csv
desc_to_csv(
        "../../desc/examples/HELIOTRON_output.h5",
        current=False,
        description="test",
        provenance="DESC examples",
        user_created="yge",
    )

# %%
# eq = load("NFP1_A+10.0_tor+0.5_mr+0.30_shift-0.30_wd+0.15_elong+1.60_wellwt+2.0_analytical_finite_beta.h5")
# load_to_database("NFP1_A+10.0_tor+0.5_mr+0.30_shift-0.30_wd+0.15_elong+1.60_wellwt+2.0_analytical",configid="rahul_db_test3", copy=True)
# eq = load("precise_QA_poincare_N3.h5")
# eq.save_to_database("precise_QA_poincare_N3",configid="precise_QA", user="yge")
save_to_db_desc("precise_QA_poincare_N3",configid="precise_QA", user="yge", copy=False, deviceid="newDevice", isDeviceNew=True, device_stell_sym=True, deviceNFP=10, config_class="QA", deviceDescription="new test device")
# Out:
# Zipping files...
# Previous desc_runs.csv has been deleted.
# Previous configurations.csv has been deleted.
# Previous devices_and_concepts.csv has been deleted.
# Creating desc_runs.csv and configurations.csv...
# Creating devices_and_concepts.csv...
# Uploading to database...
#
# Device data successfully uploaded.
# Your data is stored in Devices table with id: newDevice
# Configuration data already exists in the database with configid: precise_QA.
# DESC data already exists in the database with descrunid: 26.
# This error is thrown because there is a data in database with same outputfile: precise_QA_poincare_N3.h5.
# If you believe your data is different, try uploading again after changing .h5 file name.

# %%
from desc.examples import get
eq0 = get("DSHAPE")
plot_comparison(eqs=[eq, eq0]);
